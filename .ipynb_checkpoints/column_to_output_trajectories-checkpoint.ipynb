# %% [markdown]
# # Column to output influence
# In this file we will plot output data trajectories in plane (`Column i`,`Column 7`), with $i=[6]$, for our dataset `dados.dat`.

# %%
import numpy as np
import pandas as pd
import pylab
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib notebook

# %% [markdown]
# Let's start by reading the data file `dados.dat` and creating a dataframe.

# %%
with open('dados.dat', 'r') as infile:
    readlines = infile.readlines()
    
    df = []

    for line in readlines: 
        temp = line.split('   ')
        for elem in temp:
            if elem == '':
                temp.remove(elem)
                continue
            temp[temp.index(elem)] = float(elem.strip())
        df.append([temp[0], float(temp[1]), temp[2], 
                   temp[3], temp[4], temp[5], temp[6], temp[7]])
            
df = pd.DataFrame(df)

# %%
df
# Out:
#             0         1         2         3         4        5         6  \
# 0    3.495620  0.854140  0.749902  0.192743  43.52330  2.02056  42.43320
# 1   -4.480930  1.104820  0.485446  1.623300   9.09081  3.35892  46.48630
# 2    2.775870  1.355500  0.220990  1.053850  24.65840  1.19727  50.53940
# 3    1.696240  2.107530  0.427622  1.345510  21.36100  1.71233   8.69876
# 4   -4.580720  2.358210  0.163166  0.776062  36.92860  3.05069  12.75190
# ..        ...       ...       ...       ...       ...      ...       ...
# 821  1.779430  0.027883  0.880700  0.162503  17.66680  2.34437  21.23360
# 822  1.059680  0.529239  0.351788  1.023610  48.80190  1.52108  29.33990
# 823  0.699809  0.779917  0.087332  0.454162  14.36940  2.85944  33.39300
# 824  3.980060  1.281270  0.558420  1.315270  45.50450  2.03614  41.49920
# 825 -3.419800  1.531950  0.293964  0.745821  11.07210  3.37450  45.55230
#
#             7
# 0    84.10960
# 1    18.18030
# 2     2.80000
# 3     7.98009
# ...

# %% [markdown]
# ## Plane (Column 0, Output)

# %%
x = df.loc[:, [0]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# To try and see better the behaviour for low values of `Output` let's exclude rows where `Output`$>50$.

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [0]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 1, Output)

# %%
x = df.loc[:, [1]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [1]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 2, Output)

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [0]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [2]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 3, Output)

# %%
x = df.loc[:, [3]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [3]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 4, Output)

# %%
x = df.loc[:, [4]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [4]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 5, Output)

# %%
x = df.loc[:, [5]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [5]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %% [markdown]
# ## Plane (Column 6, Output)

# %%
x = df.loc[:, [6]].values
y = df.loc[:, [7]].values

# plot
pylab.plot(x, y, 'bo')

# %%
# filter for rows with Column 7 value lesser (or equal) than 50
filtered_y_idx = df.index[df[7]<=50]
x = df.loc[filtered_y_idx, [6]].values
y = df.loc[filtered_y_idx, [7]].values

# plot
pylab.plot(x, y, 'bo')
